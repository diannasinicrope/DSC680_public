# %%
# best example can be found here: https://www.kaggle.com/bbose71/bbc-news-classification

import pandas as pd

csv_file = '/Users/dsinicro/Desktop/Reader Revenue/Data Viz Pennlive Phase 1/pennlive_dominant_topic_fromGV.csv'

df= pd.read_csv(csv_file)
df.head()
# Out:
#                                          website_url  \
# 0  /opinion/2019/01/robert-frost-wrote-this-maste...
# 1  /opinion/2019/01/only-1-out-of-36-newly-electe...
# 2  /opinion/2019/01/can-washington-end-its-shutdo...
# 3  /opinion/2019/01/what-does-the-new-year-hold-f...
# 4  /opinion/2019/01/this-should-be-the-no-1-prior...
#
#                  first_publish_date primary_section  \
# 0  2019-01-02 13:24:53.462000+00:00         Opinion
# 1  2019-01-02 15:11:34.395000+00:00         Opinion
# 2  2019-01-02 15:51:22.092000+00:00         Opinion
# 3  2019-01-03 13:00:27.090000+00:00         Opinion
# 4  2019-01-03 13:39:16.663000+00:00         Opinion
#
#                                              content  \
# 0  <b>By Steve Hendrix </b> Whose words these are...
# 1                                                NaN
# 2  <b>By E. Fletcher McClellan</b> Divided govern...
# 3  <b>By John Dame</b> Typically, this is the sea...
# 4  <b>By Hugh Hewitt</b> Congressional Republican...
#
#                                        clavis_topics dominant_topic  \
# 0                                                 []        Opinion
# 1                                                 []        Opinion
# 2  ['Federal Courts and SCOTUS', 'Congressional E...        Opinion
# 3                        ['Strategy and Management']        Opinion
# 4                                       ['Congress']        Opinion
#
#    dominant_topic_score  pageviews
# 0                  0.04      624.0
# 1                  0.04        2.0
# 2                  0.04      390.0
# 3                  0.04      242.0
# 4                  0.04      535.0

# %%
# only keep columns that I need
df2= df[['content','dominant_topic']]
df2.head()
# Out:
#                                              content dominant_topic
# 0  <b>By Steve Hendrix </b> Whose words these are...        Opinion
# 1                                                NaN        Opinion
# 2  <b>By E. Fletcher McClellan</b> Divided govern...        Opinion
# 3  <b>By John Dame</b> Typically, this is the sea...        Opinion
# 4  <b>By Hugh Hewitt</b> Congressional Republican...        Opinion

# %%
# drop NaN for now
df2= df2.dropna()

# %%
# make new column that shows categorical numbers for categories so machine can read

df2['category_id'] = df2.dominant_topic.factorize()[0] 
df2.head()
# Out:
#                                              content dominant_topic  \
# 0  <b>By Steve Hendrix </b> Whose words these are...        Opinion
# 2  <b>By E. Fletcher McClellan</b> Divided govern...        Opinion
# 3  <b>By John Dame</b> Typically, this is the sea...        Opinion
# 4  <b>By Hugh Hewitt</b> Congressional Republican...        Opinion
# 6  <b>By Bob Quarteroni</b> I’ve long been obsess...        Opinion
#
#    category_id
# 0            0
# 2            0
# 3            0
# 4            0
# 6            0

# %%
df2.describe()
# Out:
#         category_id
# count  21113.000000
# mean      10.099986
# std        8.225374
# min        0.000000
# 25%        2.000000
# 50%        8.000000
# 75%       18.000000
# max       27.000000

# %%
# print all categories
df2['dominant_topic'].value_counts()
# Out:
# Crime                     2632
# Penn State Football       1519
# Sports                    1366
# Criminal Justice          1341
# Opinion                   1301
# HS Sports                 1210
# Politics                  1000
# Traffic                    984
# Weather                    966
# NFL - Eagles               829
# L&C - Entertainment        801
# L&C - Events               767
# NFL - Ravens               722
# Education/Schools          623
# NFL - Steelers             593
# The Tylt                   583
# L&C - Food & Dining        566
# Business                   528
# Healthcare                 481
# L&C - Nature/Seasonal      468
# Retail                     350
# Advice                     313
# Environment                301
# Obituaries                 243
# Restaurant Inspections     191
# Lottery                    171
# HS Prom                    155
# Carrers                    109
# Name: dominant_topic, dtype: int64

# %%
# Create a new pandas dataframe "category_id_df", which only has unique Categories, also sorting this list in order of category_id values
category_id_df = df2[['dominant_topic', 'category_id']].drop_duplicates().sort_values('category_id')

# %%
# Create a dictionary ( python datastructure - like a lookup table) that 
# can easily convert category names into category_ids and vice-versa
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'dominant_topic']].values)

# %%
category_id_df
# Out:
#               dominant_topic  category_id
# 0                    Opinion            0
# 9                      Crime            1
# 40       Penn State Football            2
# 65              NFL - Ravens            3
# 70                 HS Sports            4
# 83                    Sports            5
# 91                  The Tylt            6
# 121                  Weather            7
# 126             NFL - Eagles            8
# 262           NFL - Steelers            9
# 278      L&C - Food & Dining           10
# 280              Environment           11
# 281        Education/Schools           12
# 282             L&C - Events           13
# 285                 Business           14
# 287    L&C - Nature/Seasonal           15
# 288                  HS Prom           16
# 290               Obituaries           17
# 304      L&C - Entertainment           18
# 305                  Carrers           19
# 307                 Politics           20
# 327         Criminal Justice           21
# 349                   Advice           22
# 352                  Traffic           23
# 365               Healthcare           24
# 380                   Retail           25
# 972                  Lottery           26
# 1415  Restaurant Inspections           27

# %%
# Create a dictionary ( python datastructure - like a lookup table) that 
# can easily convert category names into category_ids and vice-versa
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'dominant_topic']].values)

# %%
# Group the dataframe by categories and count items ( number of news articles) in each category
df2.groupby('dominant_topic').category_id.count()
# Out:
# dominant_topic
# Advice                     313
# Business                   528
# Carrers                    109
# Crime                     2632
# Criminal Justice          1341
# Education/Schools          623
# Environment                301
# HS Prom                    155
# HS Sports                 1210
# Healthcare                 481
# L&C - Entertainment        801
# L&C - Events               767
# L&C - Food & Dining        566
# L&C - Nature/Seasonal      468
# Lottery                    171
# NFL - Eagles               829
# NFL - Ravens               722
# NFL - Steelers             593
# Obituaries                 243
# Opinion                   1301
# Penn State Football       1519
# Politics                  1000
# Restaurant Inspections     191
# Retail                     350
# Sports                    1366
# The Tylt                   583
# Traffic                    984
# Weather                    966
# Name: category_id, dtype: int64

# %%
import matplotlib

#Plot the distribution of news articles by category
df2.groupby('dominant_topic').category_id.count().plot.bar(ylim=0)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
features = tfidf.fit_transform(df2.content).toarray()
labels = df2.category_id

# %%
features.shape
# Out:
# (21113, 185625)

# %%
# Remember the dictionary created to map category names to a number ? 
category_to_id.items()
# Out:
# dict_items([('Opinion', 0), ('Crime', 1), ('Penn State Football', 2), ('NFL - Ravens', 3), ('HS Sports', 4), ('Sports', 5), ('The Tylt', 6), ('Weather', 7), ('NFL - Eagles', 8), ('NFL - Steelers', 9), ('L&C - Food & Dining', 10), ('Environment', 11), ('Education/Schools', 12), ('L&C - Events', 13), ('Business', 14), ('L&C - Nature/Seasonal', 15), ('HS Prom', 16), ('Obituaries', 17), ('L&C - Entertainment', 18), ('Carrers', 19), ('Politics', 20), ('Criminal Justice', 21), ('Advice', 22), ('Traffic', 23), ('Healthcare', 24), ('Retail', 25), ('Lottery', 26), ('Restaurant Inspections', 27)])

# %%
# The sorted function Converts dictionary items into a (sorted) list. 
# In subsequent steps - We will use this list to iterate over the categories
sorted(category_to_id.items())
# Out:
# [('Advice', 22),
#  ('Business', 14),
#  ('Carrers', 19),
#  ('Crime', 1),
#  ('Criminal Justice', 21),
#  ('Education/Schools', 12),
#  ('Environment', 11),
#  ('HS Prom', 16),
#  ('HS Sports', 4),
#  ('Healthcare', 24),
#  ('L&C - Entertainment', 18),
#  ('L&C - Events', 13),
#  ('L&C - Food & Dining', 10),
#  ('L&C - Nature/Seasonal', 15),
#  ('Lottery', 26),
#  ('NFL - Eagles', 8),
#  ('NFL - Ravens', 3),
#  ('NFL - Steelers', 9),
#  ('Obituaries', 17),
#  ('Opinion', 0),
#  ('Penn State Football', 2),
#  ('Politics', 20),
#  ('Restaurant Inspections', 27),
#  ('Retail', 25),
#  ('Sports', 5),
#  ('The Tylt', 6),
#  ('Traffic', 23),
#  ('Weather', 7)]

# %%
# use chi square to calculate print
# Use chi-square analysis to find corelation between features (importantce of words) and labels(news category) 
from sklearn.feature_selection import chi2

import numpy as np

N = 30  # We are going to look for top 3 categories

#For each category, find words that are highly corelated to it
for cat, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)                   # Do chi2 analyses of all items in this category
  indices = np.argsort(features_chi2[0])                                  # Sorts the indices of features_chi2[0] - the chi-squared stats of each feature
  feature_names = np.array(tfidf.get_feature_names())[indices]            # Converts indices to feature names ( in increasing order of chi-squared stat values)
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]         # List of single word features ( in increasing order of chi-squared stat values)
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]          # List for two-word features ( in increasing order of chi-squared stat values)
  print("# '{}':".format(cat))
  print("  . Most correlated unigrams:\n       . {}".format('\n       . '.join(unigrams[-N:]))) # Print 3 unigrams with highest Chi squared stat
  print("  . Most correlated bigrams:\n       . {}".format('\n       . '.join(bigrams[-N:]))) # Print 3 bigrams with highest Chi squared stat
# Out:
# # 'Advice':
#   . Most correlated unigrams:
#        . feel
#        . sister
#        . relationship
#        . dad
#        . feelings
#        . divorced
#        . friends
#        . friend
#        . rude
#        . los
#        . angeles
#        . box
#        . marriage
#        . married
#        . written
#        . mother
#        . founded
#        . husband
#        . van
#        . abigail
#        . ca
#        . jeanne
#        . pauline
#        . buren
#        . 90069
#        . 69440
#        . phillips
#        . dearabby
#        . abby
#        . dear
#   . Most correlated bigrams:
#        . los angeles
#        . abby recently
#        . ohio dear
#        . south dear
#        . texas dear
#        . florida dear
#        . abby husband
#        . _blank www
#        . angeles ca
#        . mother pauline
#        . com box
#        . abby href
#        . phillips founded
#        . phillips contact
#        . pauline phillips
#        . abby written
#        . contact dear
#        . founded mother
#        . jeanne phillips
#        . van buren
#        . abigail van
#        . written abigail
#        . ca 90069
#        . 69440 los
#        . box 69440
#        . known jeanne
#        . buren known
#        . www dearabby
#        . dearabby com
#        . dear abby
# # 'Business':
#   . Most correlated unigrams:
#        . liquidation
#        . refinery
#        . customers
#        . markets
#        . equifax
#        . sears
#        . earnings
#        . lampert
#        . revenue
#        . parx
#        . retail
#        . sugarhouse
#        . dehaan
#        . gallon
#        . prices
#        . retailers
#        . shoppers
#        . store
#        . amazon
#        . retailer
#        . cents
#        . sales
#        . gaming
#        . company
#        . gambling
#        . bankruptcy
#        . casino
#        . gasbuddy
#        . casinos
#        . stores
#   . Most correlated bigrams:
#        . library closed
#        . _blank gasbuddy
#        . things remembered
#        . stock exchange
#        . slot machines
#        . penn national
#        . average gas
#        . cents lower
#        . head petroleum
#        . petroleum analysis
#        . dehaan head
#        . average price
#        . _blank amazon
#        . regular hours
#        . www gasbuddy
#        . filed bankruptcy
#        . patrick dehaan
#        . 11 bankruptcy
#        . gambling expansion
#        . control board
#        . stores open
#        . chapter 11
#        . table games
#        . company said
#        . gasbuddy com
#        . wood mode
#        . gas prices
#        . pennsylvania gaming
#        . gaming control
#        . sports betting
# # 'Carrers':
#   . Most correlated unigrams:
#        . format
#        . uno
#        . lovett
#        . differentiate
#        . networking
#        . presenting
#        . qualifications
#        . sam
#        . keywords
#        . dear
#        . careeradvice
#        . candidacy
#        . transferable
#        . formatting
#        . keyword
#        . employer
#        . greeters
#        . greeter
#        . catlin
#        . 888
#        . 570
#        . strategist
#        . samantha
#        . resume
#        . 614
#        . 3442
#        . nolan
#        . branding
#        . dearsam
#        . nolanbranding
#   . Most correlated bigrams:
#        . nolan advanced
#        . branding resume
#        . career expert
#        . 888 brand
#        . expert founder
#        . branding strategist
#        . ceo nolan
#        . branding services
#        . brand 614
#        . advanced personal
#        . strategist career
#        . resume career
#        . sam reach
#        . search question
#        . services visit
#        . question dear
#        . com dearsam
#        . samantha href
#        . samantha nolan
#        . 570 3442
#        . 614 570
#        . reach samantha
#        . information nolan
#        . mailto dearsam
#        . job search
#        . dear sam
#        . nolan branding
#        . dearsam nolanbranding
#        . www nolanbranding
#        . nolanbranding com
# # 'Crime':
#   . Most correlated unigrams:
#        . shot
#        . girl
#        . accused
#        . investigation
#        . gunshot
#        . old
#        . robbery
#        . custody
#        . arraigned
#        . dead
#        . hospital
#        . felony
#        . authorities
#        . identified
#        . homicide
#        . aggravated
#        . coroner
#        . bail
#        . arrested
#        . incident
#        . charges
#        . block
#        . assault
#        . charged
#        . suspect
#        . woman
#        . man
#        . officers
#        . shooting
#        . police
#   . Most correlated bigrams:
#        . information asked
#        . officers arrived
#        . indecent assault
#        . police investigating
#        . county prison
#        . taken custody
#        . old man
#        . harrisburg police
#        . coroner office
#        . county coroner
#        . police 717
#        . asked contact
#        . 000 bail
#        . preliminary hearing
#        . said police
#        . com daily
#        . daily buzz
#        . buzz 2019
#        . city police
#        . told police
#        . online court
#        . aggravated assault
#        . police department
#        . court documents
#        . according police
#        . township police
#        . year old
#        . state police
#        . police say
#        . police said
# # 'Criminal Justice':
#   . Most correlated unigrams:
#        . pacourts
#        . courts
#        . crimes
#        . panel
#        . appeal
#        . filed
#        . appeals
#        . link
#        . case
#        . superior
#        . prosecutors
#        . pleaded
#        . conviction
#        . attorney
#        . docket
#        . cases
#        . accessed
#        . sheets
#        . convicted
#        . sentenced
#        . judicial
#        . guilty
#        . unified
#        . trial
#        . archived
#        . prison
#        . sentence
#        . jury
#        . court
#        . judge
#   . Most correlated bigrams:
#        . judicial list
#        . isn visible
#        . court panel
#        . superior court
#        . lebanon adams
#        . court docket
#        . perry lancaster
#        . york lebanon
#        . cases filed
#        . accessed href
#        . new cases
#        . ve provided
#        . docket sheets
#        . cases cases
#        . case list
#        . tomorrow new
#        . counties ve
#        . list criminal
#        . cases listed
#        . sheets case
#        . courts dauphin
#        . link court
#        . pennlive accessed
#        . archived pennlive
#        . replaced tomorrow
#        . listed archived
#        . pacourts pennsylvania
#        . pennsylvania unified
#        . unified judicial
#        . criminal cases
# # 'Education/Schools':
#   . Most correlated unigrams:
#        . meeting
#        . enrollment
#        . administrators
#        . faculty
#        . recovery
#        . appointed
#        . principal
#        . audit
#        . auditors
#        . appoint
#        . knight
#        . solicitor
#        . takeover
#        . samuels
#        . academic
#        . districts
#        . student
#        . sybil
#        . hasan
#        . district
#        . schools
#        . ellison
#        . board
#        . burney
#        . receivership
#        . teachers
#        . school
#        . education
#        . superintendent
#        . students
#   . Most correlated bigrams:
#        . district superintendent
#        . appoint receiver
#        . district html
#        . pedro rivera
#        . financial recovery
#        . district financial
#        . business manager
#        . james ellison
#        . area school
#        . board president
#        . board meeting
#        . superintendent sybil
#        . education secretary
#        . school year
#        . board member
#        . district officials
#        . state takeover
#        . said district
#        . janet samuels
#        . sybil knight
#        . recovery officer
#        . chief recovery
#        . school districts
#        . recovery plan
#        . department education
#        . knight burney
#        . board members
#        . harrisburg school
#        . school district
#        . school board
# # 'Environment':
#   . Most correlated unigrams:
#        . overflows
#        . sewage
#        . af53127e507978
#        . wjmckelvey
#        . wmckelvey
#        . radiation
#        . suez
#        . water
#        . island
#        . emissions
#        . municipalities
#        . pipelines
#        . plant
#        . energy
#        . mariner
#        . pollution
#        . radioactive
#        . gas
#        . nrc
#        . decommissioning
#        . pfas
#        . meltdown
#        . stormwater
#        . dep
#        . reactor
#        . sewer
#        . exelon
#        . environmental
#        . nuclear
#        . tmi
#   . Most correlated bigrams:
#        . exelon generation
#        . farr said
#        . water sewer
#        . storm water
#        . waste plant
#        . plant closes
#        . nuclear regulatory
#        . http water
#        . water pennlive
#        . water authority
#        . protection agency
#        . nuclear energy
#        . regulatory commission
#        . spent fuel
#        . 03 mile
#        . region water
#        . mariner east
#        . power plant
#        . island accident
#        . power station
#        . drinking water
#        . nuclear waste
#        . department environmental
#        . natural gas
#        . partial meltdown
#        . island nuclear
#        . nuclear plant
#        . environmental protection
#        . nuclear power
#        . mile island
# # 'HS Prom':
#   . Most correlated unigrams:
#        . angelonia
#        . hosta
#        . catmint
#        . school
#        . impatiens
#        . geraniums
#        . hatcheries
#        . stocking
#        . bloom
#        . coreopsis
#        . agastache
#        . perennial
#        . botanical
#        . letort
#        . brunnera
#        . sedum
#        . phlox
#        . blooms
#        . coneflower
#        . euphorbia
#        . snip
#        . radisson
#        . proms
#        . held
#        . weigel
#        . salvia
#        . photographers
#        . eden
#        . commencement
#        . prom
#   . Most correlated bigrams:
#        . radisson hotel
#        . county technical
#        . held 17
#        . george weigel
#        . hershey grantville
#        . held april
#        . high school
#        . photos html
#        . held 11
#        . forum harrisburg
#        . photographers captured
#        . view community
#        . trout fishing
#        . school 2019
#        . school commencement
#        . hotel camp
#        . pennlive photographers
#        . commencement ceremony
#        . hotel swatara
#        . held 18
#        . prom photos
#        . commencement held
#        . lion hotel
#        . school held
#        . 2019 prom
#        . held commencement
#        . eden resort
#        . resort lancaster
#        . school prom
#        . prom held
# # 'HS Sports':
#   . Most correlated unigrams:
#        . quarterfinals
#        . tallied
#        . palmyra
#        . championships
#        . 4a
#        . semifinals
#        . crusaders
#        . paced
#        . scored
#        . cougars
#        . catholic
#        . 5a
#        . points
#        . cd
#        . class
#        . 6a
#        . chipped
#        . trojans
#        . victory
#        . rbis
#        . valley
#        . innings
#        . bishop
#        . trinity
#        . cliff
#        . 3a
#        . mcdevitt
#        . cedar
#        . 2a
#        . piaa
#   . Most correlated bigrams:
#        . penn conference
#        . lancaster catholic
#        . tri valley
#        . upper dauphin
#        . 12 points
#        . wrestling championships
#        . mifflin county
#        . susquehanna twp
#        . lampeter strasburg
#        . steel high
#        . manheim central
#        . boiling springs
#        . runs scored
#        . class 4a
#        . cd east
#        . manheim twp
#        . class 5a
#        . class 6a
#        . game high
#        . district class
#        . piaa class
#        . red land
#        . central dauphin
#        . lower dauphin
#        . bishop mcdevitt
#        . cumberland valley
#        . class 2a
#        . class 3a
#        . cedar cliff
#        . mid penn
# # 'Healthcare':
#   . Most correlated unigrams:
#        . vaccination
#        . marijuana
#        . infections
#        . pinnacle
#        . drug
#        . cigarettes
#        . care
#        . overdoses
#        . wellspan
#        . outbreak
#        . addiction
#        . vaping
#        . infection
#        . deaths
#        . vaccinated
#        . prevention
#        . opioids
#        . mumps
#        . disease
#        . cdc
#        . vaccine
#        . flu
#        . doctors
#        . opioid
#        . symptoms
#        . medical
#        . fda
#        . measles
#        . health
#        . patients
#   . Most correlated bigrams:
#        . dr rachel
#        . flesh eating
#        . marijuana program
#        . pinnacle said
#        . health human
#        . measles cases
#        . levine said
#        . secretary health
#        . rachel levine
#        . according health
#        . cdc gov
#        . www cdc
#        . overdose deaths
#        . human services
#        . flu cases
#        . health care
#        . confirmed cases
#        . cases reported
#        . food drug
#        . upmc pinnacle
#        . flu season
#        . medical marijuana
#        . drug administration
#        . control prevention
#        . centers disease
#        . health department
#        . disease control
#        . health officials
#        . department health
#        . state health
# # 'L&C - Entertainment':
#   . Most correlated unigrams:
#        . nominations
#        . disney
#        . characters
#        . singer
#        . comic
#        . winnings
#        . thrones
#        . contestant
#        . avengers
#        . song
#        . premiere
#        . movies
#        . endgame
#        . comics
#        . theaters
#        . comscore
#        . actress
#        . emmy
#        . awards
#        . marvel
#        . comedy
#        . films
#        . episode
#        . airs
#        . trebek
#        . film
#        . movie
#        . actor
#        . jeopardy
#        . holzhauer
#   . Most correlated bigrams:
#        . universal pictures
#        . hailey waller
#        . videos href
#        . jimmy mowery
#        . cinematic universe
#        . marvel cinematic
#        . war ii
#        . pl5jyaykaowifm8mw3hi_q9wsqhg3rzlgk click
#        . star wars
#        . af mil
#        . aircraft display
#        . list pl5jyaykaowifm8mw3hi_q9wsqhg3rzlgk
#        . aircraft videos
#        . dozens military
#        . click dozens
#        . joint base
#        . www jeopardy
#        . 2019 bloomberg
#        . com entertainment
#        . american idol
#        . music awards
#        . ken jennings
#        . holzhauer won
#        . box office
#        . avengers endgame
#        . game thrones
#        . jeopardy com
#        . warner bros
#        . alex trebek
#        . james holzhauer
# # 'L&C - Events':
#   . Most correlated unigrams:
#        . kennywood
#        . amusement
#        . arts
#        . performing
#        . sale
#        . coaster
#        . songs
#        . park
#        . art
#        . exhibits
#        . entertainment
#        . vendors
#        . theatre
#        . artists
#        . br
#        . museum
#        . woodstock
#        . concerts
#        . event
#        . info
#        . hersheyentertainment
#        . ticketmaster
#        . band
#        . tour
#        . hersheypark
#        . music
#        . admission
#        . tickets
#        . festival
#        . concert
#   . Most correlated bigrams:
#        . riverfront park
#        . concert series
#        . hershey entertainment
#        . harrisburg br
#        . face painting
#        . coming hershey
#        . com 717
#        . food vendors
#        . br href
#        . com www
#        . live music
#        . strong br
#        . org 717
#        . tickets start
#        . tickets sale
#        . sale 10
#        . com events
#        . woodstock 50
#        . br free
#        . org www
#        . www ticketmaster
#        . br strong
#        . info 717
#        . br info
#        . hersheypark stadium
#        . free admission
#        . info href
#        . www hersheyentertainment
#        . hersheyentertainment com
#        . ticketmaster com
# # 'L&C - Food & Dining':
#   . Most correlated unigrams:
#        . spicy
#        . vineyards
#        . salad
#        . onion
#        . breweries
#        . bacon
#        . diners
#        . restaurants
#        . burgers
#        . tasting
#        . wineries
#        . sandwich
#        . burger
#        . food
#        . cream
#        . chocolate
#        . butter
#        . brewery
#        . beer
#        . winery
#        . sauce
#        . flavors
#        . sandwiches
#        . chicken
#        . flavor
#        . wine
#        . restaurant
#        . wines
#        . cheese
#        . menu
#   . Most correlated bigrams:
#        . gluten free
#        . cabernet sauvignon
#        . harrisburg 717
#        . food chain
#        . impossible whopper
#        . butter cups
#        . participating restaurants
#        . county winery
#        . craft beer
#        . cabernet franc
#        . tasting room
#        . oldest brewery
#        . spicy chicken
#        . http blog
#        . limited edition
#        . fast food
#        . reese peanut
#        . wine 2017
#        . blog pennlive
#        . menu items
#        . mac cheese
#        . limited time
#        . chicken sandwich
#        . plant based
#        . wine 2018
#        . food 2019
#        . ice cream
#        . peanut butter
#        . com wine
#        . com food
# # 'L&C - Nature/Seasonal':
#   . Most correlated unigrams:
#        . alligator
#        . wildaboutpa
#        . foliage
#        . enclosure
#        . sightings
#        . mating
#        . hunting
#        . zoo
#        . ocearch
#        . commission
#        . nest
#        . cwd
#        . salamander
#        . snakes
#        . sharks
#        . hellbender
#        . birds
#        . amphibian
#        . bird
#        . fish
#        . habitat
#        . hunters
#        . elk
#        . bear
#        . animals
#        . animal
#        . deer
#        . shark
#        . wildlife
#        . species
#   . Most correlated bigrams:
#        . wildlife management
#        . fish boat
#        . www ocearch
#        . official amphibian
#        . shark attack
#        . ocearch org
#        . marcus schneck
#        . black bears
#        . wasting disease
#        . schneck reached
#        . shark week
#        . bald eagles
#        . species pennsylvania
#        . chronic wasting
#        . game commissioners
#        . wildwood crest
#        . santa anita
#        . hunting seasons
#        . com mschneck
#        . ocean city
#        . wildlife service
#        . mschneck pennlive
#        . eastern hellbender
#        . com wildaboutpa
#        . fish wildlife
#        . great white
#        . black bear
#        . white shark
#        . pennsylvania game
#        . game commission
# # 'Lottery':
#   . Most correlated unigrams:
#        . saturdays
#        . rico
#        . puerto
#        . reset
#        . pools
#        . millions
#        . payout
#        . prize
#        . 3x
#        . 302
#        . 292
#        . 2x
#        . 575
#        . payment
#        . numbers
#        . megaplier
#        . wednesdays
#        . megamillions
#        . tuesdays
#        . islands
#        . powerplay
#        . sum
#        . virgin
#        . drawings
#        . lump
#        . mega
#        . drawing
#        . lottery
#        . powerball
#        . jackpot
#   . Most correlated bigrams:
#        . ticket gives
#        . deadline purchase
#        . saturdays deadline
#        . gives 292
#        . rico ticket
#        . powerball held
#        . champions drawings
#        . joining hall
#        . million chance
#        . hall powerball
#        . eastern wednesdays
#        . 59 eastern
#        . jackpot winner
#        . millions jackpot
#        . jackpot html
#        . columbia virgin
#        . drawings held
#        . 292 million
#        . million lottery
#        . powerball jackpot
#        . million jackpot
#        . drawing jackpot
#        . virgin islands
#        . lottery jackpot
#        . lump sum
#        . estimated jackpot
#        . 44 states
#        . sum payment
#        . winning numbers
#        . mega millions
# # 'NFL - Eagles':
#   . Most correlated unigrams:
#        . arcega
#        . posts
#        . ertz
#        . sudfeld
#        . agholor
#        . roseman
#        . delivered
#        . doug
#        . foles
#        . alshon
#        . eaglesonpl
#        . inbox
#        . jeffery
#        . desean
#        . pennstate
#        . youtube
#        . playlist
#        . carson
#        . philadelphia
#        . gallen
#        . bydanieljtgallen
#        . pederson
#        . wentz
#        . topics
#        . danieljtgallen
#        . pl5jyaykaowie_f_f7b6abu2suhm05zsxp
#        . dgallen
#        . tag
#        . philadelphiaeagles
#        . eagles
#   . Most correlated bigrams:
#        . doug pederson
#        . pl5jyaykaowie_f_f7b6abu2suhm05zsxp youtube
#        . follow href
#        . posts facebook
#        . football posts
#        . facebook follow
#        . eagles coverage
#        . pennlive philadelphia
#        . eagles football
#        . carson wentz
#        . com dgallen
#        . daniel gallen
#        . covers href
#        . mailto dgallen
#        . gallen covers
#        . bydanieljtgallen facebook
#        . danieljtgallen twitter
#        . com bydanieljtgallen
#        . www twitter
#        . com danieljtgallen
#        . philadelphiaeagles 2019
#        . list pl5jyaykaowie_f_f7b6abu2suhm05zsxp
#        . eagles pennlive
#        . dgallen pennlive
#        . philadelphiaeagles philadelphia
#        . http topics
#        . com tag
#        . com philadelphiaeagles
#        . topics pennlive
#        . philadelphia eagles
# # 'NFL - Ravens':
#   . Most correlated unigrams:
#        . flacco
#        . humphrey
#        . martindale
#        . andrews
#        . tavon
#        . ingram
#        . youtube
#        . afc
#        . weddle
#        . judon
#        . onwuasor
#        . mosley
#        . rookie
#        . aaron
#        . nfl
#        . suggs
#        . boykin
#        . marquise
#        . jackson
#        . owings
#        . decosta
#        . lamar
#        . kasinitz
#        . ravensonpennlive
#        . pl5jyaykaowifbtwqxogtl2byatypuimom
#        . harbaugh
#        . akasinitz
#        . aaronkazreports
#        . baltimore
#        . ravens
#   . Most correlated bigrams:
#        . quarterback lamar
#        . http pennlive
#        . mills md
#        . coach john
#        . owings mills
#        . com akasinitz
#        . harbaugh said
#        . john harbaugh
#        . http twitter
#        . com twitter
#        . com ravensonpennlive
#        . ravens coverage
#        . pl5jyaykaowifbtwqxogtl2byatypuimom youtube
#        . ravens 2019
#        . list pl5jyaykaowifbtwqxogtl2byatypuimom
#        . aaronkazreports follow
#        . pennlive ravens
#        . aaron kasinitz
#        . ravensonpennlive facebook
#        . lamar jackson
#        . kasinitz covers
#        . covers baltimore
#        . mailto akasinitz
#        . ravens pennlive
#        . aaronkazreports aaronkazreports
#        . com aaronkazreports
#        . ravens baltimore
#        . akasinitz pennlive
#        . com baltimore
#        . baltimore ravens
# # 'NFL - Steelers':
#   . Most correlated unigrams:
#        . gentry
#        . tuitt
#        . switzer
#        . bush
#        . chickillo
#        . edmunds
#        . okorafor
#        . latrobe
#        . pouncey
#        . watt
#        . snell
#        . heyward
#        . conner
#        . moncrief
#        . rooney
#        . feiler
#        . dupree
#        . diontae
#        . juju
#        . colbert
#        . dobbs
#        . haden
#        . antonio
#        . rudolph
#        . sutton
#        . schuster
#        . pittsburgh
#        . roethlisberger
#        . tomlin
#        . steelers
#   . Most correlated bigrams:
#        . vance mcdonald
#        . cameron heyward
#        . maurkice pouncey
#        . ramon foster
#        . james washington
#        . mike hilton
#        . vince williams
#        . bud dupree
#        . mark barron
#        . matt feiler
#        . jaylen samuels
#        . joshua dobbs
#        . _blank steelers
#        . cameron sutton
#        . diontae johnson
#        . joe haden
#        . devin bush
#        . sean davis
#        . kevin colbert
#        . james conner
#        . juju smith
#        . mason rudolph
#        . pittsburgh steelers
#        . smith schuster
#        . ben roethlisberger
#        . antonio brown
#        . steelers 2019
#        . tomlin said
#        . com steelers
#        . mike tomlin
# # 'Obituaries':
#   . Most correlated unigrams:
#        . officiating
#        . jean
#        . 28168
#        . links
#        . barbara
#        . lochstampfor
#        . 4629
#        . preceded
#        . 4623
#        . 31208
#        . ann
#        . mary
#        . amp
#        . doris
#        . 22858
#        . betty
#        . sr
#        . nieces
#        . grandchildren
#        . shirley
#        . nephews
#        . helen
#        . dorothy
#        . surviving
#        . fhid
#        . aspx
#        . obituary
#        . pid
#        . obits
#        . obituaries
#   . Most correlated bigrams:
#        . click href
#        . aspx james
#        . aspx john
#        . edition patriot
#        . aspx mary
#        . aspx robert
#        . appear today
#        . today edition
#        . listed links
#        . links photos
#        . news listed
#        . jr href
#        . obituaries appear
#        . obituaries href
#        . photos used
#        . amp fhid
#        . used submitted
#        . submitted obituaries
#        . obituaries click
#        . read obituaries
#        . guest book
#        . jr amp
#        . http obits
#        . https obits
#        . amp pid
#        . obituary aspx
#        . pennlive obituary
#        . com obituaries
#        . obits pennlive
#        . obituaries pennlive
# # 'Opinion':
#   . Most correlated unigrams:
#        . emissions
#        . elected
#        . america
#        . abortion
#        . voters
#        . mueller
#        . citizens
#        . republicans
#        . fossil
#        . politicians
#        . jtures
#        . wage
#        . climate
#        . president
#        . socialism
#        . democrats
#        . singel
#        . gerow
#        . tax
#        . socialist
#        . economic
#        . economy
#        . legislators
#        . democracy
#        . lagrange
#        . congress
#        . government
#        . political
#        . americans
#        . trump
#   . Most correlated bigrams:
#        . college lagrange
#        . edu twitter
#        . edu jtures
#        . tures professor
#        . georgia reached
#        . www lagrange
#        . edu lagrange
#        . columnist1 verizon
#        . amp elephants
#        . john tures
#        . fossil fuel
#        . column appears
#        . american people
#        . climate change
#        . tax cuts
#        . gerow ceo
#        . minimum wage
#        . face state
#        . lagrange college
#        . governor pennsylvania
#        . verizon net
#        . gov wolf
#        . opinion contributor
#        . work appears
#        . jtures lagrange
#        . lagrange edu
#        . charlie gerow
#        . mark singel
#        . pennlive opinion
#        . president trump
# # 'Penn State Football':
#   . Most correlated unigrams:
#        . state
#        . saquon
#        . citrus
#        . matos
#        . statecollege
#        . cain
#        . micah
#        . trace
#        . transfer
#        . hamler
#        . stevens
#        . barkley
#        . lions247
#        . parsons
#        . beaver
#        . football
#        . flounders
#        . mcsorley
#        . pennstatefootball
#        . idaho
#        . redshirt
#        . pickel
#        . clifford
#        . 247sports
#        . psu
#        . franklin
#        . recruiting
#        . nittany
#        . penn
#        . lions
#   . Most correlated bigrams:
#        . greg pickel
#        . citrus bowl
#        . white game
#        . micah parsons
#        . tommy stevens
#        . state article
#        . today penn
#        . pickel pennlive
#        . bob flounders
#        . trace mcsorley
#        . spring practice
#        . college football
#        . com college
#        . 247sports com
#        . football news
#        . com pennstatefootball
#        . ohio state
#        . lions news
#        . https 247sports
#        . blue white
#        . college penn
#        . sean clifford
#        . franklin said
#        . pennstatefootball 2019
#        . beaver stadium
#        . coach james
#        . state football
#        . nittany lions
#        . james franklin
#        . penn state
# # 'Politics':
#   . Most correlated unigrams:
#        . pelosi
#        . mueller
#        . immigration
#        . wolf
#        . elections
#        . campaign
#        . political
#        . politics
#        . voters
#        . congressional
#        . committee
#        . border
#        . house
#        . biden
#        . democrat
#        . congress
#        . donald
#        . lawmakers
#        . rep
#        . gop
#        . president
#        . republicans
#        . sen
#        . presidential
#        . election
#        . democrats
#        . senate
#        . republican
#        . democratic
#        . trump
#   . Most correlated bigrams:
#        . trump administration
#        . mike pence
#        . justice department
#        . www legis
#        . robert mueller
#        . president mike
#        . counsel robert
#        . house senate
#        . government shutdown
#        . speaker nancy
#        . judiciary committee
#        . nancy pelosi
#        . joe biden
#        . state house
#        . majority leader
#        . tom wolf
#        . democratic presidential
#        . trump campaign
#        . com politics
#        . border wall
#        . gov tom
#        . special counsel
#        . washington ap
#        . house speaker
#        . said trump
#        . special election
#        . trump said
#        . white house
#        . donald trump
#        . president donald
# # 'Restaurant Inspections':
#   . Most correlated unigrams:
#        . sanitizing
#        . bain
#        . mff
#        . cleanable
#        . freezer
#        . ppm
#        . inspectors
#        . static
#        . dust
#        . overseen
#        . utensils
#        . surfaces
#        . shelving
#        . accumulation
#        . wash
#        . grease
#        . washing
#        . ware
#        . type
#        . stored
#        . residue
#        . sanitizer
#        . sink
#        . corrected
#        . inspections
#        . observed
#        . violations
#        . shutterstock
#        . inspection
#        . illustration
#   . Most correlated bigrams:
#        . notes cases
#        . cases violations
#        . inspectors leave
#        . restaurant inspectors
#        . food debris
#        . violations corrected
#        . inspections overseen
#        . lancaster inspection
#        . food residue
#        . complaint violations
#        . regular compliance
#        . follow violations
#        . walk cooler
#        . food contact
#        . type complaint
#        . opening violations
#        . type follow
#        . wash sink
#        . compliance violations
#        . type opening
#        . hand wash
#        . violations observed
#        . food facility
#        . violations shutterstock
#        . regular violations
#        . 2019 inspection
#        . shutterstock illustration
#        . type regular
#        . inspection type
#        . inspection date
# # 'Retail':
#   . Most correlated unigrams:
#        . showroom
#        . acquired
#        . township
#        . mall
#        . sells
#        . relocated
#        . cbd
#        . townhomes
#        . shopping
#        . retail
#        . dealership
#        . store
#        . company
#        . located
#        . estate
#        . apartments
#        . commons
#        . space
#        . realty
#        . neatest
#        . bedrooms
#        . opened
#        . tenant
#        . newsletters
#        . location
#        . tenants
#        . spaces
#        . business
#        . square
#        . buzz
#   . Most correlated bigrams:
#        . city mall
#        . commercial real
#        . opened new
#        . new office
#        . ridge village
#        . real estate
#        . store sells
#        . grand opening
#        . store opened
#        . tag cool
#        . new location
#        . features pennlive
#        . expected open
#        . feet space
#        . new facility
#        . opening celebration
#        . business 2018
#        . shopping center
#        . com business
#        . cool spaces
#        . newsletters sign
#        . 000 square
#        . square feet
#        . square foot
#        . pennlive newsletters
#        . sign pennlive
#        . buzz href
#        . buzz business
#        . tag business
#        . business buzz
# # 'Sports':
#   . Most correlated unigrams:
#        . em
#        . mlb
#        . buffaloes
#        . puck
#        . team
#        . ssimmers
#        . tvl
#        . derby
#        . susquenita
#        . soundcloud
#        . baseball
#        . championship
#        . hander
#        . elmora
#        . simmers
#        . mustang
#        . pitch
#        . win
#        . mustangs
#        . assists
#        . 482680904
#        . scored
#        . tournament
#        . alvanitakis
#        . phillies
#        . game
#        . league
#        . blackhawks
#        . linder
#        . sportsbyblinder
#   . Most correlated bigrams:
#        . users incorrect
#        . note scores
#        . kentucky derby
#        . 2019 sean
#        . em em
#        . west perry
#        . sports 2019
#        . added offer
#        . simmers ssimmers
#        . ssimmers pennlive
#        . steelers update
#        . john alvanitakis
#        . hershey bears
#        . soundcloud com
#        . 482680904 steelers
#        . https soundcloud
#        . sean simmers
#        . user 482680904
#        . mail sports
#        . alvanitakis reached
#        . sports perrycountytimes
#        . league world
#        . world series
#        . sportsbyblinder target
#        . _blank sportsbyblinder
#        . little league
#        . brian linder
#        . com sportsbyblinder
#        . follow brian
#        . linder twitter
# # 'The Tylt':
#   . Most correlated unigrams:
#        . keydra
#        . jessie
#        . tran
#        . matter
#        . community
#        . blaeser
#        . vote
#        . share
#        . opinion
#        . hear
#        . data
#        . present
#        . counts
#        . join
#        . advance
#        . focused
#        . culture
#        . progress
#        . pop
#        . llc
#        . meaningful
#        . engage
#        . opinions
#        . literally
#        . actively
#        . instagram
#        . conversations
#        . debates
#        . tylt
#        . thetylt
#   . Most correlated bigrams:
#        . opinions vote
#        . opinion counts
#        . present meaningful
#        . topics matter
#        . place opinion
#        . tylt place
#        . tylt focused
#        . progress tylt
#        . conversations news
#        . tylt advance
#        . actively engage
#        . counts literally
#        . focused debates
#        . literally tylt
#        . community opportunity
#        . community present
#        . data debates
#        . matter actively
#        . property join
#        . conversations progress
#        . join twitter
#        . vote topics
#        . instagram href
#        . facebook love
#        . thetylt facebook
#        . thetylt href
#        . thetylt instagram
#        . debates conversations
#        . thetylt thetylt
#        . com thetylt
# # 'Traffic':
#   . Most correlated unigrams:
#        . detour
#        . 83
#        . bridge
#        . highway
#        . scene
#        . trailer
#        . 81
#        . roadway
#        . motorists
#        . interchange
#        . vehicles
#        . road
#        . closed
#        . driver
#        . tractor
#        . westbound
#        . crews
#        . lane
#        . eastbound
#        . route
#        . vehicle
#        . northbound
#        . exit
#        . interstate
#        . southbound
#        . 511pa
#        . penndot
#        . traffic
#        . lanes
#        . crash
#   . Most correlated bigrams:
#        . crash cleared
#        . morning crash
#        . using seat
#        . crash involving
#        . crash reported
#        . penndot officials
#        . mile marker
#        . department transportation
#        . killed crash
#        . lanes exit
#        . seat belt
#        . lane restriction
#        . lanes closed
#        . according penndot
#        . county crash
#        . stop traffic
#        . traffic reported
#        . multi vehicle
#        . northbound lanes
#        . interstate 83
#        . www 511pa
#        . crash closed
#        . southbound lanes
#        . crash occurred
#        . interstate 81
#        . according 511pa
#        . tractor trailer
#        . 511pa com
#        . vehicle crash
#        . crash happened
# # 'Weather':
#   . Most correlated unigrams:
#        . precipitation
#        . sunshine
#        . freezing
#        . service
#        . inches
#        . expected
#        . gusts
#        . meteorologist
#        . forecasters
#        . flooding
#        . tornado
#        . mph
#        . thunderstorm
#        . clouds
#        . winds
#        . partly
#        . low
#        . storms
#        . temperatures
#        . cloudy
#        . showers
#        . thunderstorms
#        . forecast
#        . sunny
#        . storm
#        . rain
#        . snow
#        . skies
#        . accuweather
#        . weather
#   . Most correlated bigrams:
#        . weather updates
#        . winter storm
#        . night partly
#        . clear skies
#        . inches snow
#        . com en
#        . _blank accuweather
#        . partly cloudy
#        . look forecast
#        . forecast harrisburg
#        . according national
#        . service state
#        . chance showers
#        . skies high
#        . accuweather reports
#        . high near
#        . com weather
#        . showers thunderstorms
#        . en weather
#        . weather news
#        . partly sunny
#        . www accuweather
#        . sunny skies
#        . accuweather com
#        . percent chance
#        . sunny high
#        . skies low
#        . cloudy skies
#        . national weather
#        . weather service

# %%
### DS: Above was re-run on 2020-02-05 to find the lists of top 30 for each category
